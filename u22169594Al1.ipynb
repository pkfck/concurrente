# %% [markdown]
# <!-- PROFILE LINK -->
# <h1 style = "text-align:center; font-size: 30px">PROGRAMACIÓN CONCURRENTE Y DISTRIBUIDA</h1>
# <a href ="https://github.com/pkfck/Al1">
# <img src="https://avatars.githubusercontent.com/u/101180395?v=4" style="float:left;vertical-align:centre" width="110" height="110" title = "Christian Vlaldimir Sucuzhanay Arevalo 21535220">
# <a href ="https://github.com/pkfck/Al1">
# <img src="https://media-exp1.licdn.com/dms/image/C4D0BAQEu_Aa76fcmPw/company-logo_200_200/0/1630998679429?e=2159024400&v=beta&t=2feC9GG7RWCWizTqsK5HzDWB1TL2DOQuAVwnMf6FFvk" title = "M41" alt="UE" width="110" height="110" style="float:right;vertical-align:centre">

# %% [markdown]
# ## MEMORIA DESCRIPTIVA

# %% [markdown]
# INTRODUCCIÓN:
#
#     Esta será mi memoria sobre la acticidad Al1, donde explicaré sobre su funcionamiento.
#
#
# CÓDIGO:
#
# ![image.png](attachment:70a00b60-5559-49a5-895e-444538e1eacf.png)
#
# Aquí inicializamos desde python el servidor, introduciendo los cinco primeros números de nuestro número de expediente (22169), para asignarlo como nuestro puerto.
# Después de introducir el puerto indicado, nos dará nuestra IP, con el que trabajaremos mas tarde.
#
# A) Como nos pide el enunciado, instanciamos 6 clientes usando la IP recientemente sacada y nuestro respectivo puerto (22169).
#
# ![Captura de pantalla (1401).png](attachment:95cd96f2-09c2-496a-9bb0-2375e098695b.png)
#
# B) Al iniciar como cliente y tras haber introducido la IP y el puerto. Podremos elegir un nickname que sera mostrado por pantalla. Además de que si este usuario envía un mensaje, este mismo será mostrado en el Servidor, y en todos los usuarios conectados.
#
# ![Captura de pantalla (1406).png](attachment:87a3e32f-fe91-4151-9495-a7948e2267ce.png)
# ![Captura de pantalla (1407).png](attachment:70e85788-e7b2-437f-8b29-770f35fd5794.png)
# ![Captura de pantalla (1408).png](attachment:a3afd441-f85a-448f-9867-d18cf5045585.png)
#
# C) A través del servidor creamos la lista de Usuarios conectados en ese momento.
#
# ![Captura de pantalla (1410).png](attachment:63f790c3-8c33-43fb-baee-ad67e9c4e9e5.png)
#
# Como podemos confirmar, actualmente están conectados solo dos usuarios (Uno y Dos).
#
# D) Ahora generaremos el historial de Chat de los Usuarios, guardando los mensajes en un nloc de notas.
#
# ![Captura de pantalla (1418).png](attachment:22c1367a-c8a1-402e-b606-6d83c129af15.png)
# ![Captura de pantalla (1419).png](attachment:6f2cd9ab-a651-4ccc-888f-9d01b88d1a2f.png)
